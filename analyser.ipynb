# %%
# Step 1: Import the main analyzer class
# Make sure analyzer.py and sentimentdataset.csv are in the same folder as this notebook.
from analyzer import SentimentAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns

# Set a nice style for the plots
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)

# Step 2: Create an instance of the analyzer
# This will automatically load, clean, and process the data.
analyzer = SentimentAnalyzer('sentimentdataset.csv')

# --- Now, let's perform our Exploratory Data Analysis (EDA) ---

# EDA Question 1: What is the overall sentiment of the posts?
print("\n--- Analyzing Overall Sentiment Distribution ---")
analyzer.plot_sentiment_distribution()

# EDA Question 2: Which social media platform is the most engaging?
print("\n--- Comparing Average Likes by Platform ---")
analyzer.compare_engagement_by_platform(metric='likes')

print("\n--- Comparing Average Retweets by Platform ---")
analyzer.compare_engagement_by_platform(metric='retweets')

# EDA Question 3: Does the sentiment of a post affect its performance?
print("\n--- Analyzing the Impact of Sentiment on Engagement ---")
analyzer.analyze_sentiment_impact_on_engagement()

# EDA Question 4: What are the most popular topics being discussed?
print("\n--- Identifying Top Trending Hashtags ---")
top_tags = analyzer.find_top_hashtags(n=15)

print("\n\n✅ Analysis Complete!")
# Out:
# ✅ Successfully loaded and processed 732 posts.
#
# --- Analyzing Overall Sentiment Distribution ---
# c:\Users\ansar\OneDrive\Desktop\SocialMediaPerformance\analyzer.py:101: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='viridis')
# --- Comparing Average Likes by Platform ---
# c:\Users\ansar\OneDrive\Desktop\SocialMediaPerformance\analyzer.py:125: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_engagement.index, y=avg_engagement.values, palette='mako')
# --- Comparing Average Retweets by Platform ---
# c:\Users\ansar\OneDrive\Desktop\SocialMediaPerformance\analyzer.py:125: FutureWarning:
#
# ...
